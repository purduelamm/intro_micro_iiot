# %% [markdown]
# <a href="https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/index_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview of the course
#
#
# Through lab sessions, you will perform a series of hands-on activities, and mainly learn tangible practical skills for implementation of IIoT (Industrial Internet of Things).
#
# - Middleware: MTConnect
#
#   a. Data agent: local data server
#
#   b. Data adapter: pushing data to agent

# %% [markdown]
# ## **Getting started**
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
ft_in_a_mile = 1760*3
ft_in_a_mile
# Out:
# 5280

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
inches_in_a_mile = ft_in_a_mile * 12
inches_in_a_mile
# Out:
# 63360

# %% [markdown]
# ## Nomenclature
#
# Throughout the lab material, you will often work through multiple colab notebooks for each lab. For notebook organization, the following numbering scheme was used:
#
# **For the title**: Lab [lab number].[colab notebook #]
#
# **For sections within each lab**: [colab notebook #].[section #]
#
# **For tasks**: [colab notebook #].[Task #]
#
# For example,
#
# *Prelab 1.1; Prelab 1.2; Prelab 1.3; and Prelab 1.4* are all Prelab 1, seperated into multiple colab notebooks to help distinguish parts of the lab. Then, inside of Prelab 1.3, there is heading 3.1 which defines part 1, inside of colab 3. Then, Task 3.1.

# %% [markdown]
# ## Table of Content
# ---
# ### **Introduction**
#
# [Intro to Colab Notebooks](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/intro/Introduction_to_Colab_Notebooks.ipynb) &nbsp;|&nbsp;
# [Basics of Python](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/intro/Basics_of_Python.ipynb) &nbsp;|&nbsp;
#
# ---
#
# ### **Lab 4 - Middleware 1: MTConnect agent**
# #### Prelab 4 activity
# [PL4 Colab 1](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab4/PL4_Colab1.ipynb) &nbsp;|&nbsp;
#
# #### Lab 4 activity
# [L4 Colab 1](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab4/L4_Colab1.ipynb) &nbsp;|&nbsp;
# [L4 Colab 2](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab4/L4_Colab2.ipynb) &nbsp;|&nbsp;
# [L4 Colab 3](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab4/L4_Colab3.ipynb) &nbsp;|&nbsp;
#
# ---
#
# ### **Lab 5 - Middleware 2: MTConnect adapter**
# #### Prelab 5 activity
# [PL5 Colab 1](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab5/PL5_Colab1.ipynb) &nbsp;|&nbsp;
#
# #### Lab 5 activity
# [L5 Colab 1](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab5/L5_Colab1.ipynb) &nbsp;|&nbsp;
# [L5 Colab 2](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab5/L5_Colab2.ipynb) &nbsp;|&nbsp;
# [L5 Colab 3](https://colab.research.google.com/github/purduelamm/intro_micro_iiot/blob/main/lab/lab5/L5_Colab3.ipynb) &nbsp;|&nbsp;
#
# ---

# %% [markdown]
# <br></br>
#
# Get back to [Github repo main](https://github.com/purduelamm/intro_micro_iiot)
